# %%
import numpy as np
import seaborn as sns
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.neighbors import KNeighborsClassifier

np.random.seed(0)

# %% [markdown]
# ## Parte 1: Preparación de los Datos

# %%
data=pd.read_csv("balance.csv", index_col=0)

# %%
data.head(3)
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 1   14.891   3606     283      2   34         11    Male      No     Yes
# 2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 3  104.593   7075     514      4   71         11    Male      No      No
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580

# %%
pd.plotting.scatter_matrix(data, alpha=0.4)
# Out:
# array([[<AxesSubplot:xlabel='Income', ylabel='Income'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Income'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Income'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Income'>,
#         <AxesSubplot:xlabel='Age', ylabel='Income'>,
#         <AxesSubplot:xlabel='Education', ylabel='Income'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Income'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Age', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Education', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Limit'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Rating'>,
# ...

# %%
sns.pairplot(data,hue="Balance")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Parte 1: Preparación

# %%
data["Gender"]=pd.Series(np.searchsorted(["Male","Female"], data.Gender.values), data.index)
data.head(3)
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 1   14.891   3606     283      2   34         11       0      No     Yes
# 2  106.025   6645     483      3   82         15       0     Yes     Yes
# 3  104.593   7075     514      4   71         11       0      No      No
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580

# %%
data.tail(3)
# Out:
#      Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 398  57.872   4171     321      5   67         12       0      No     Yes
# 399  37.728   2525     192      1   44         13       0      No     Yes
# 400  18.701   5524     415      5   64          7       0      No      No
#
#      Ethnicity  Balance
# 398  Caucasian      138
# 399  Caucasian        0
# 400      Asian      966

# %%
data["Married"]=pd.Series(np.searchsorted(["Yes","No"], data.Married.values), data.index)

# %%
data.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student  Married  \
# 1   14.891   3606     283      2   34         11       0      No        2
# 2  106.025   6645     483      3   82         15       0     Yes        2
# 3  104.593   7075     514      4   71         11       0      No        0
# 4  148.924   9504     681      3   36         11       0      No        0
# 5   55.882   4897     357      2   68         16       0      No        2
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580
# 4      Asian      964
# 5  Caucasian      331

# %%
data["Student"]=pd.Series(np.searchsorted(["Yes","No"], data.Student.values), data.index)

# %%
data.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1   14.891   3606     283      2   34         11       0        0        2
# 2  106.025   6645     483      3   82         15       0        2        2
# 3  104.593   7075     514      4   71         11       0        0        0
# 4  148.924   9504     681      3   36         11       0        0        0
# 5   55.882   4897     357      2   68         16       0        0        2
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580
# 4      Asian      964
# 5  Caucasian      331

# %%
df=pd.get_dummies(data.Ethnicity)
df
# Out:
#      African American  Asian  Caucasian
# 1                   0      0          1
# 2                   0      1          0
# 3                   0      1          0
# 4                   0      1          0
# 5                   0      0          1
# ..                ...    ...        ...
# 396                 0      0          1
# 397                 1      0          0
# 398                 0      0          1
# 399                 0      0          1
# 400                 0      1          0
#
# [400 rows x 3 columns]

# %%
df.drop("African American", axis="columns", inplace=True)
df
# Out:
#      Asian  Caucasian
# 1        0          1
# 2        1          0
# 3        1          0
# 4        1          0
# 5        0          1
# ..     ...        ...
# 396      0          1
# 397      0          0
# 398      0          1
# 399      0          1
# 400      1          0
#
# [400 rows x 2 columns]

# %%
df2=pd.concat([data,df], axis=1)
df2
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        2
# 2    106.025   6645     483      3   82         15       0        2        2
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       0        0        0
# 5     55.882   4897     357      2   68         16       0        0        2
# ..       ...    ...     ...    ...  ...        ...     ...      ...      ...
# 396   12.096   4100     307      3   32         13       0        0        2
# 397   13.364   3838     296      5   65         17       0        0        0
# 398   57.872   4171     321      5   67         12       0        0        2
# 399   37.728   2525     192      1   44         13       0        0        2
# 400   18.701   5524     415      5   64          7       0        0        0
#
# ...

# %% [markdown]
# ## Parte 2: Ajustar el modelo

# %%
y=df2["Balance"]
y
# Out:
# 1      333
# 2      903
# 3      580
# 4      964
# 5      331
#       ...
# 396    560
# 397    480
# 398    138
# 399      0
# 400    966
# Name: Balance, Length: 400, dtype: int64

# %%
X=df2.drop(["Balance","Ethnicity"], axis="columns")
X
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        2
# 2    106.025   6645     483      3   82         15       0        2        2
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       0        0        0
# 5     55.882   4897     357      2   68         16       0        0        2
# ..       ...    ...     ...    ...  ...        ...     ...      ...      ...
# 396   12.096   4100     307      3   32         13       0        0        2
# 397   13.364   3838     296      5   65         17       0        0        0
# 398   57.872   4171     321      5   67         12       0        0        2
# 399   37.728   2525     192      1   44         13       0        0        2
# 400   18.701   5524     415      5   64          7       0        0        0
#
#      Asian  Caucasian
# ...

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y, shuffle=True, test_size=0.25)

# %%
model=LinearRegression()
regressor=model.fit(X_train, y_train)

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': False,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 11,
#  'coef_': array([-7.87155092e+00,  1.95222438e-01,  1.09789227e+00,  1.80293313e+01,
#         -6.18754011e-01, -7.35730753e-01,  1.91846539e-13,  2.09524701e+02,
#         -3.88305682e+00,  9.85434687e+00,  1.84161233e+00]),
#  '_residues': array([], dtype=float64),
#  'rank_': 10,
#  'singular_': array([4.07805333e+04, 3.82605031e+02, 2.86676971e+02, 2.05355110e+02,
#         5.41715868e+01, 1.96471906e+01, 1.67704387e+01, 1.04468344e+01,
#         9.78350827e+00, 5.16020527e+00, 1.47220520e-16]),
#  'intercept_': -489.4997286874635}

# %%
model.coef_
# Out:
# array([-7.87155092e+00,  1.95222438e-01,  1.09789227e+00,  1.80293313e+01,
#        -6.18754011e-01, -7.35730753e-01,  1.91846539e-13,  2.09524701e+02,
#        -3.88305682e+00,  9.85434687e+00,  1.84161233e+00])

# %%
yhat=regressor.predict(X_test)

# %%
r2_score(y_test,yhat)
# Out:
# 0.9574915804108061

# %%
fig, ax=plt.subplots(figsize=(15,8))
ax.scatter(y_test, yhat, color="red", marker="+", s=45)
ax.set_title("Verdadero vs Calculado")
ax.set_ylabel("yCalculado")
ax.set_xlabel("Real")
# Out:
# Text(0.5, 0, 'Real')

# %%
plt.hist(df2.Balance, 100);

# %%
df2["Is_Zero"]=np.nan; df2
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        2
# 2    106.025   6645     483      3   82         15       0        2        2
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       0        0        0
# 5     55.882   4897     357      2   68         16       0        0        2
# ..       ...    ...     ...    ...  ...        ...     ...      ...      ...
# 396   12.096   4100     307      3   32         13       0        0        2
# 397   13.364   3838     296      5   65         17       0        0        0
# 398   57.872   4171     321      5   67         12       0        0        2
# 399   37.728   2525     192      1   44         13       0        0        2
# 400   18.701   5524     415      5   64          7       0        0        0
#
# ...

# %% [markdown]
# ## Parte 3: Clasificador y regresor

# %%
part3=df2; part3
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        2
# 2    106.025   6645     483      3   82         15       0        2        2
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       0        0        0
# 5     55.882   4897     357      2   68         16       0        0        2
# ..       ...    ...     ...    ...  ...        ...     ...      ...      ...
# 396   12.096   4100     307      3   32         13       0        0        2
# 397   13.364   3838     296      5   65         17       0        0        0
# 398   57.872   4171     321      5   67         12       0        0        2
# 399   37.728   2525     192      1   44         13       0        0        2
# 400   18.701   5524     415      5   64          7       0        0        0
#
# ...

# %%
part3["Is_Zero"]=np.where(part3["Balance"]==0, True, False)
part3.drop(["Ethnicity"], axis="columns", inplace=True)
part3
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        2
# 2    106.025   6645     483      3   82         15       0        2        2
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       0        0        0
# 5     55.882   4897     357      2   68         16       0        0        2
# ..       ...    ...     ...    ...  ...        ...     ...      ...      ...
# 396   12.096   4100     307      3   32         13       0        0        2
# 397   13.364   3838     296      5   65         17       0        0        0
# 398   57.872   4171     321      5   67         12       0        0        2
# 399   37.728   2525     192      1   44         13       0        0        2
# 400   18.701   5524     415      5   64          7       0        0        0
#
#      Balance  Asian  Caucasian  Is_Zero
# ...

# %%
y_knn=part3["Is_Zero"]
X_knn=part3.drop("Is_Zero", axis="columns")
X_knn_train, X_knn_test, y_knn_train, y_knn_test= train_test_split(X_knn, y_knn, test_size=0.25, shuffle=True)

# %%
y_knn
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: Is_Zero, Length: 400, dtype: bool

# %%
#Knn tiene 1 hyperparametro
parameters={"n_neighbors":range(1,100)}
knn_model=KNeighborsClassifier()
gs=GridSearchCV(knn_model, parameters, cv=5, n_jobs=1, verbose=1, return_train_score=True)
gs.fit(X_knn_train, y_knn_train)
# Out:
# Fitting 5 folds for each of 99 candidates, totalling 495 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=1,
#              param_grid={'n_neighbors': range(1, 100)}, return_train_score=True,
#              verbose=1)

# %%
gs.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
gs.score(X_knn_test, y_knn_test)
# Out:
# 0.97

# %%
yhat_knn=gs.predict(X_knn_test)
pd.Series(yhat_knn).value_counts()
# Out:
# False    84
# True     16
# dtype: int64

# %%
select=pd.Series(y_knn).map(lambda x: True if x==False else False)
final_df=part3[select].drop("Is_Zero", axis=1)
final_df
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        2
# 2    106.025   6645     483      3   82         15       0        2        2
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       0        0        0
# 5     55.882   4897     357      2   68         16       0        0        2
# ..       ...    ...     ...    ...  ...        ...     ...      ...      ...
# 395   49.794   5758     410      4   40          8       0        0        0
# 396   12.096   4100     307      3   32         13       0        0        2
# 397   13.364   3838     296      5   65         17       0        0        0
# 398   57.872   4171     321      5   67         12       0        0        2
# 400   18.701   5524     415      5   64          7       0        0        0
#
#      Balance  Asian  Caucasian
# ...

# %%
y_final=final_df["Balance"]

# %%
X_final=final_df.drop("Balance", axis=1,)
X_final
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        2
# 2    106.025   6645     483      3   82         15       0        2        2
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       0        0        0
# 5     55.882   4897     357      2   68         16       0        0        2
# ..       ...    ...     ...    ...  ...        ...     ...      ...      ...
# 395   49.794   5758     410      4   40          8       0        0        0
# 396   12.096   4100     307      3   32         13       0        0        2
# 397   13.364   3838     296      5   65         17       0        0        0
# 398   57.872   4171     321      5   67         12       0        0        2
# 400   18.701   5524     415      5   64          7       0        0        0
#
#      Asian  Caucasian
# ...

# %%
X_train, X_test, y_train, y_test= train_test_split(X_final, y_final, test_size=0.25)

# %%
linear_model=LinearRegression()
linear_regressor=linear_model.fit(X_train, y_train)

# %%
ypred=linear_model.predict(X_test)

# %%
r2_score(y_test,ypred)
# Out:
# 0.9994611093971126

# %%
fig, ax=plt.subplots(figsize=(15,8))
ax.scatter(y_test,ypred, color="cyan", marker="+")
ax.set_title("Y verdaderovs Y calculado")
ax.set_ylabel ("y real")
ax.set_xlabel ("y calculado")
# Out:
# Text(0.5, 0, 'y calculado')

# %%
fig, ax=plt.subplots(figsize=(15,8))
ax.scatter(y_test, (y_test-ypred), color="red", marker="*")
ax.axhline(y=0)
#ax.set_title("Y verdaderovs Y calculado")
#ax.set_ylabel ("y real")
#ax.set_xlabel ("y calculado")
